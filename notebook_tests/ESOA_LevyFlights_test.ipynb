# %%
#import
import time
import csv
import os
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %% [markdown]
# ***loading data***

# %%
X = pd.read_csv('feature_selection/X_selected.csv')
target = pd.read_csv('feature_selection/y.csv')
y = target['MEDV']

#standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

#split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# # **ESOA** ***main code :***

# %%
# -*- coding: utf-8 -*-
"""
Created on Sat Jul 23 14:35:31 2022

@author: 山抹微云
"""
# In[]
class ESO:
    def __init__(self, func, n_dim, size_pop, max_iter, lb, ub, constraint_ueq=None):

        self.func       = func
        self.n_dim      = n_dim
        self.size_pop = size_pop
        self.max_iter = max_iter
        self.lb   = np.array(lb)
        self.ub   = np.array(ub)

        # adam's learning rate of weight estimate
        self.beta1 = 0.9
        self.beta2 = 0.99
        self.m = np.zeros((self.size_pop, self.n_dim))
        self.v = np.zeros((self.size_pop, self.n_dim))
        self.w = np.random.uniform(-1, 1, size=(self.size_pop, self.n_dim))
        self.g = np.empty_like(self.w)

        # location, fitness, and estimate fitness
        self.x = np.random.uniform(0, 1, size=(self.size_pop, self.n_dim)) * (self.ub-self.lb) + self.lb
        self.y = np.empty(self.size_pop)
        self.p_y = self.y.copy()

        # best fitness history and estimate error history
        self.y_hist = []
        self.err = []

        # individual best location, gradient direction, and fitness
        self.x_hist_best = self.x.copy()
        self.g_hist_best = np.empty_like(self.x)
        self.y_hist_best = np.ones(size_pop)*np.inf

        # group best location, gradient direction, and fitness
        self.x_global_best = self.x[0].copy()
        self.g_global_best = np.zeros(self.n_dim)
        self.y_global_best = func(self.x[0])

        self.hop = self.ub - self.lb


    def checkBound(self,x):
        return np.clip(x, self.lb, self.ub)


    def refill(self,V):
        V = V.reshape(len(V), 1)
        V = np.tile(V, self.n_dim)
        return V

    def gradientEstimate(self, g_temp):

        # Indivual direction
        p_d = self.x_hist_best - self.x
        p_d_sum = p_d.sum(axis=1)
        p_d_sum = self.refill(p_d_sum)
        f_p_bias = self.y_hist_best - self.y
        f_p_bias = self.refill(f_p_bias)
        p_d *= f_p_bias
        p_d /= (p_d_sum+np.spacing(1))*(p_d_sum+np.spacing(1))

        d_p = p_d + self.g_hist_best

        # Group direction
        c_d = self.x_global_best - self.x
        c_d_sum = c_d.sum(axis=1)
        c_d_sum = self.refill(c_d_sum)
        f_c_bias = self.y_global_best - self.y
        f_c_bias = self.refill(f_c_bias)
        c_d *= f_c_bias
        c_d /= (c_d_sum+np.spacing(1))*(p_d_sum+np.spacing(1))

        d_g = c_d + self.g_global_best

        # Advice
        r1 = np.random.random(self.size_pop)
        r1 = self.refill(r1)

        r2 = np.random.random(self.size_pop)
        r2 = self.refill(r2)

        r3 = np.random.random(self.size_pop)
        r3 = self.refill(r3)

        self.g = r1 * g_temp + r2 * d_p + r3 * d_g
        g_sum = self.g.sum(axis=1)
        g_sum = self.refill(g_sum)
        self.g /= (g_sum+np.spacing(1))

    def weightUpdate(self):
        # Update weight
        self.m = self.beta1*self.m+(1-self.beta1)*self.g
        self.v = self.beta2*self.v+(1-self.beta2)*self.g**2
        self.w = self.w - self.m/(np.sqrt(self.v)+np.spacing(1))

    def updateSurface(self):
        self.y = np.array([self.func(self.x[i, :]) for i in range(self.size_pop)]).reshape(self.size_pop)
        self.p_y = np.sum(self.w*self.x, axis=1)
        self.err.append(np.abs(self.y-self.p_y).min())
        p = self.p_y-self.y
        p = self.refill(p)
        g_temp = p*self.x

        mask = self.y < self.y_hist_best
        self.y_hist_best = np.where(mask, self.y, self.y_hist_best)

        mask = self.refill(mask)
        self.x_hist_best = np.where(mask, self.x, self.x_hist_best)
        self.g_hist_best = np.where(mask, g_temp, self.g_hist_best)

        g_hist_sum = self.refill(np.sqrt((self.g_hist_best**2).sum(axis=1)))
        self.g_hist_best /= (g_hist_sum + np.spacing(1))

        # Data Insecure
        if self.y.min() < self.y_global_best:
            self.y_global_best = self.y.min()
            self.x_global_best = self.x[self.y.argmin(), :]
            self.g_global_best = g_temp[self.y.argmin(), :]
            self.g_global_best /= np.sqrt(np.sum(self.g_global_best**2))

        self.gradientEstimate(g_temp)

        self.weightUpdate()

    def get_levy_step(self, beta=1.5):
        sigma = (math.gamma(1 + beta) * math.sin(math.pi * beta / 2) / (math.gamma((1 + beta) / 2) * beta * 2**((beta - 1) / 2)))**(1 / beta)
        u = np.random.randn(self.size_pop, self.n_dim) * sigma
        v = np.random.randn(self.size_pop, self.n_dim)
        step = u / abs(v)**(1 / beta)
        return step

    def randomSearch(self):
        # Levy flight based random search
        levy_step = self.get_levy_step()
        x_levy = self.x + 0.01 * levy_step * self.hop # Scale the Levy step

        x_levy = self.checkBound(x_levy)
        y_levy = np.array([self.func(x_levy[i, :]) for i in range(self.size_pop)])

        # Original random search (tan-based)
        r = np.random.uniform(-np.pi / 2, np.pi / 2, size=(self.size_pop, self.n_dim))
        x_n = self.x + np.tan(r) * self.hop/( 1 + self.times) *0.5
        x_n = self.checkBound(x_n)
        y_n = np.array([self.func(x_n[i, :]) for i in range(self.size_pop)])

        # Random step search
        d = self.x_hist_best - self.x
        d_g = self.x_global_best - self.x
        r = np.random.uniform(0, 0.5, size=(self.size_pop, self.n_dim))
        r2 = np.random.uniform(0, 0.5, size=(self.size_pop, self.n_dim))
        x_m = (1-r-r2) * self.x + r * d + r2 * d_g
        x_m = self.checkBound(x_m)
        y_m = np.array([self.func(x_m[i, :]) for i in range(self.size_pop)])

        return x_m, y_m, x_n, y_n, x_levy, y_levy


    def adviceSearch(self):
        x_o = self.x + np.exp(-self.times/(0.1*self.max_iter)) * 0.1 * self.hop * self.g
        x_o = self.checkBound(x_o)
        y_o = np.array([self.func(x_o[i, :]) for i in range(self.size_pop)])
        return x_o, y_o


    def run(self, verbose=True, csv_filename="eso_log.csv"):
        start_time = time.time()

        # CSV setup
        header = ["Iteration", "Best_Fitness", "Elapsed_Time", "Estimated_Total_Time"]
        if os.path.exists(csv_filename):
            os.remove(csv_filename)
        with open(csv_filename, mode="w", newline="") as file:
            writer = csv.writer(file)
            writer.writerow(header)

        for self.times in range(self.max_iter):
            iter_start = time.time()

            self.updateSurface()
            x_m, y_m, x_n, y_n, x_levy, y_levy = self.randomSearch()
            x_o, y_o = self.adviceSearch()

            # Comparison including Levy flight
            x_i = np.empty_like(self.x)
            y_i = np.empty_like(self.y)
            x_summary = np.array([x_m, x_n, x_o, x_levy])
            y_summary = np.column_stack((y_m, y_n, y_o, y_levy))
            y_summary[np.isnan(y_summary)] = np.inf
            i_ind = y_summary.argmin(axis=1)
            for i in range(self.size_pop):
                y_i[i] = y_summary[i, i_ind[i]]
                x_i[i,:] = x_summary[i_ind[i]][i]

            # Update location
            mask = y_i < self.y
            self.y = np.where(mask, y_i, self.y)
            mask = self.refill(mask)
            self.x = np.where(mask, x_i, self.x)
            mask = y_i < self.y_hist_best
            self.y_hist_best = np.where(mask, y_i, self.y_hist_best)
            mask = self.refill(mask)
            self.x_hist_best = np.where(mask, x_i, self.x_hist_best)

            if y_i.min() < self.y_global_best:
                self.y_global_best = y_i[y_i.argmin()]
                self.x_global_best = x_i[y_i.argmin(), :]
            else:
                ran = np.random.random(self.size_pop)
                ran = self.refill(ran)
                ran[mask] = 1
                mask = ran < 0.3
                self.x = np.where(mask, x_i, self.x)
                self.y = np.where(mask[:, 0], y_i, self.y)

            self.y_hist.append(self.y_global_best.copy())

            # Timing & verbose output
            iter_time = time.time() - iter_start
            elapsed = time.time() - start_time
            estimated_total = (elapsed / (self.times + 1)) * self.max_iter
            if verbose:
                print(f"Iter {self.times + 1}/{self.max_iter} | Best Fitness: {self.y_global_best:.6f} | "
                      f"Iter Time: {iter_time:.2f}s | Elapsed: {elapsed:.2f}s | Est. Total: {estimated_total:.2f}s")

            # Write to CSV
            with open(csv_filename, mode="a", newline="") as file:
                writer = csv.writer(file)
                writer.writerow([self.times + 1, self.y_global_best, elapsed, estimated_total])
        return self.x_global_best, self.y_global_best, self.err

# %% [markdown]
# # model **SVR**

# %%
c = 1.0
e = 0.1
g = 0.1
model_svr = SVR(kernel='rbf', C=c, epsilon=e, gamma=g)

# Ensure the feature names match between X_train and X_test

model_svr.fit(X_train, y_train)

y_pred = model_svr.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error

# Calculate R^2 score (accuracy)
accuracy = r2_score(y_test, y_pred)

# Calculate RMSE
mse = mean_squared_error(y_test, y_pred)

print(f"Mean Squared Error (SVR without ESOA optimization): {mse}")
print(f"Accuracy Score (SVR without ESOA optimization): {accuracy} %")
# Out:
# Mean Squared Error (SVR without ESOA optimization): 19.332281781282678
# Accuracy Score (SVR without ESOA optimization): 0.7363795927585206 %

# %% [markdown]
# # inserting **SVR** function to feed the ESOA

# %%
def func(hyperparams):
    C, epsilon, gamma = hyperparams
    model = SVR(C=C, epsilon=epsilon, gamma=gamma)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    return mean_squared_error(y_test, y_pred)

# %%
model = ESO(
    func=func,
    n_dim=3,
    size_pop=256,
    max_iter=75,
    lb = [0.1, 0.001 , 1e-5],
    ub = [100, 1, 10],

)

# %%
#running the model
best_params, best_score, err = model.run()
# Out:
# Iter 1/75 | Best Fitness: 8.588735 | Iter Time: 17.59s | Elapsed: 17.59s | Est. Total: 1319.05s
# Iter 2/75 | Best Fitness: 8.480393 | Iter Time: 17.84s | Elapsed: 35.43s | Est. Total: 1328.46s
# Iter 3/75 | Best Fitness: 8.459692 | Iter Time: 18.69s | Elapsed: 54.11s | Est. Total: 1352.81s
# Iter 4/75 | Best Fitness: 8.459692 | Iter Time: 18.22s | Elapsed: 72.33s | Est. Total: 1356.23s
# Iter 5/75 | Best Fitness: 8.459692 | Iter Time: 21.40s | Elapsed: 93.74s | Est. Total: 1406.04s
# Iter 6/75 | Best Fitness: 8.459692 | Iter Time: 23.54s | Elapsed: 117.27s | Est. Total: 1465.92s
# Iter 7/75 | Best Fitness: 8.459692 | Iter Time: 24.56s | Elapsed: 141.84s | Est. Total: 1519.67s
# Iter 8/75 | Best Fitness: 8.459692 | Iter Time: 25.75s | Elapsed: 167.58s | Est. Total: 1571.11s
# Iter 9/75 | Best Fitness: 8.459692 | Iter Time: 26.03s | Elapsed: 193.62s | Est. Total: 1613.50s
# Iter 10/75 | Best Fitness: 8.459019 | Iter Time: 41.09s | Elapsed: 234.71s | Est. Total: 1760.33s
# Iter 11/75 | Best Fitness: 8.455722 | Iter Time: 26.18s | Elapsed: 260.89s | Est. Total: 1778.83s
# Iter 12/75 | Best Fitness: 8.447191 | Iter Time: 30.98s | Elapsed: 291.88s | Est. Total: 1824.24s
# Iter 13/75 | Best Fitness: 8.447191 | Iter Time: 33.61s | Elapsed: 325.49s | Est. Total: 1877.85s
# Iter 14/75 | Best Fitness: 8.447191 | Iter Time: 37.83s | Elapsed: 363.32s | Est. Total: 1946.36s
# Iter 15/75 | Best Fitness: 8.447191 | Iter Time: 36.87s | Elapsed: 400.19s | Est. Total: 2000.97s
# Iter 16/75 | Best Fitness: 8.447191 | Iter Time: 35.16s | Elapsed: 435.35s | Est. Total: 2040.71s
# Iter 17/75 | Best Fitness: 8.447191 | Iter Time: 40.80s | Elapsed: 476.16s | Est. Total: 2100.69s
# Iter 18/75 | Best Fitness: 8.447191 | Iter Time: 39.59s | Elapsed: 515.75s | Est. Total: 2148.96s
# Iter 19/75 | Best Fitness: 8.447191 | Iter Time: 39.45s | Elapsed: 555.20s | Est. Total: 2191.56s
# Iter 20/75 | Best Fitness: 8.442625 | Iter Time: 34.81s | Elapsed: 590.00s | Est. Total: 2212.51s
# Iter 21/75 | Best Fitness: 8.442625 | Iter Time: 34.97s | Elapsed: 624.98s | Est. Total: 2232.06s
# Iter 22/75 | Best Fitness: 8.442625 | Iter Time: 35.31s | Elapsed: 660.29s | Est. Total: 2250.99s
# Iter 23/75 | Best Fitness: 8.442625 | Iter Time: 35.08s | Elapsed: 695.37s | Est. Total: 2267.51s
# Iter 24/75 | Best Fitness: 8.442625 | Iter Time: 33.33s | Elapsed: 728.70s | Est. Total: 2277.20s
# Iter 25/75 | Best Fitness: 8.442625 | Iter Time: 30.66s | Elapsed: 759.36s | Est. Total: 2278.08s
# Iter 26/75 | Best Fitness: 8.442625 | Iter Time: 31.12s | Elapsed: 790.48s | Est. Total: 2280.23s
# Iter 27/75 | Best Fitness: 8.442625 | Iter Time: 31.54s | Elapsed: 822.02s | Est. Total: 2283.40s
# Iter 28/75 | Best Fitness: 8.442625 | Iter Time: 31.91s | Elapsed: 853.94s | Est. Total: 2287.33s
# Iter 29/75 | Best Fitness: 8.442625 | Iter Time: 31.37s | Elapsed: 885.30s | Est. Total: 2289.58s
# Iter 30/75 | Best Fitness: 8.442625 | Iter Time: 31.68s | Elapsed: 916.99s | Est. Total: 2292.47s
# Iter 31/75 | Best Fitness: 8.442625 | Iter Time: 31.36s | Elapsed: 948.35s | Est. Total: 2294.40s
# Iter 32/75 | Best Fitness: 8.442625 | Iter Time: 32.12s | Elapsed: 980.47s | Est. Total: 2297.97s
# Iter 33/75 | Best Fitness: 8.442625 | Iter Time: 32.33s | Elapsed: 1012.80s | Est. Total: 2301.81s
# Iter 34/75 | Best Fitness: 8.442625 | Iter Time: 31.80s | Elapsed: 1044.59s | Est. Total: 2304.25s
# Iter 35/75 | Best Fitness: 8.442625 | Iter Time: 31.43s | Elapsed: 1076.02s | Est. Total: 2305.76s
# Iter 36/75 | Best Fitness: 8.442625 | Iter Time: 30.98s | Elapsed: 1107.00s | Est. Total: 2306.25s
# Iter 37/75 | Best Fitness: 8.442625 | Iter Time: 31.71s | Elapsed: 1138.71s | Est. Total: 2308.20s
# Iter 38/75 | Best Fitness: 8.442625 | Iter Time: 31.66s | Elapsed: 1170.38s | Est. Total: 2309.95s
# Iter 39/75 | Best Fitness: 8.442625 | Iter Time: 31.32s | Elapsed: 1201.70s | Est. Total: 2310.96s
# Iter 40/75 | Best Fitness: 8.442625 | Iter Time: 31.23s | Elapsed: 1232.93s | Est. Total: 2311.74s
# Iter 41/75 | Best Fitness: 8.442625 | Iter Time: 31.63s | Elapsed: 1264.56s | Est. Total: 2313.21s
# Iter 42/75 | Best Fitness: 8.442625 | Iter Time: 31.92s | Elapsed: 1296.48s | Est. Total: 2315.14s
# Iter 43/75 | Best Fitness: 8.442625 | Iter Time: 32.66s | Elapsed: 1329.14s | Est. Total: 2318.27s
# Iter 44/75 | Best Fitness: 8.442625 | Iter Time: 31.99s | Elapsed: 1361.14s | Est. Total: 2320.12s
# Iter 45/75 | Best Fitness: 8.442625 | Iter Time: 32.69s | Elapsed: 1393.83s | Est. Total: 2323.05s
# Iter 46/75 | Best Fitness: 8.442625 | Iter Time: 37.26s | Elapsed: 1431.10s | Est. Total: 2333.31s
# Iter 47/75 | Best Fitness: 8.442625 | Iter Time: 37.27s | Elapsed: 1468.36s | Est. Total: 2343.13s
# Iter 48/75 | Best Fitness: 8.442234 | Iter Time: 36.86s | Elapsed: 1505.23s | Est. Total: 2351.92s
# Iter 49/75 | Best Fitness: 8.442234 | Iter Time: 37.32s | Elapsed: 1542.54s | Est. Total: 2361.04s
# Iter 50/75 | Best Fitness: 8.442234 | Iter Time: 37.32s | Elapsed: 1579.87s | Est. Total: 2369.80s
# Iter 51/75 | Best Fitness: 8.442234 | Iter Time: 36.82s | Elapsed: 1616.69s | Est. Total: 2377.48s
# Iter 52/75 | Best Fitness: 8.442234 | Iter Time: 36.48s | Elapsed: 1653.17s | Est. Total: 2384.38s
# Iter 53/75 | Best Fitness: 8.442234 | Iter Time: 36.94s | Elapsed: 1690.10s | Est. Total: 2391.66s
# Iter 54/75 | Best Fitness: 8.442234 | Iter Time: 37.12s | Elapsed: 1727.23s | Est. Total: 2398.93s
# Iter 55/75 | Best Fitness: 8.442234 | Iter Time: 37.00s | Elapsed: 1764.23s | Est. Total: 2405.77s
# Iter 56/75 | Best Fitness: 8.442234 | Iter Time: 36.90s | Elapsed: 1801.13s | Est. Total: 2412.22s
# Iter 57/75 | Best Fitness: 8.442234 | Iter Time: 37.31s | Elapsed: 1838.44s | Est. Total: 2419.00s
# Iter 58/75 | Best Fitness: 8.442234 | Iter Time: 37.19s | Elapsed: 1875.63s | Est. Total: 2425.39s
# Iter 59/75 | Best Fitness: 8.442234 | Iter Time: 37.04s | Elapsed: 1912.68s | Est. Total: 2431.37s
# Iter 60/75 | Best Fitness: 8.442234 | Iter Time: 37.02s | Elapsed: 1949.70s | Est. Total: 2437.12s
# Iter 61/75 | Best Fitness: 8.442234 | Iter Time: 37.23s | Elapsed: 1986.93s | Est. Total: 2442.94s
# Iter 62/75 | Best Fitness: 8.442234 | Iter Time: 36.70s | Elapsed: 2023.62s | Est. Total: 2447.93s
# Iter 63/75 | Best Fitness: 8.442234 | Iter Time: 37.21s | Elapsed: 2060.84s | Est. Total: 2453.38s
# Iter 64/75 | Best Fitness: 8.442206 | Iter Time: 37.39s | Elapsed: 2098.23s | Est. Total: 2458.86s
# Iter 65/75 | Best Fitness: 8.442160 | Iter Time: 39.24s | Elapsed: 2137.47s | Est. Total: 2466.31s
# Iter 66/75 | Best Fitness: 8.442117 | Iter Time: 38.33s | Elapsed: 2175.80s | Est. Total: 2472.50s
# Iter 67/75 | Best Fitness: 8.442117 | Iter Time: 38.06s | Elapsed: 2213.86s | Est. Total: 2478.20s
# Iter 68/75 | Best Fitness: 8.442117 | Iter Time: 37.75s | Elapsed: 2251.61s | Est. Total: 2483.40s
# Iter 69/75 | Best Fitness: 8.442117 | Iter Time: 37.55s | Elapsed: 2289.17s | Est. Total: 2488.22s
# Iter 70/75 | Best Fitness: 8.442066 | Iter Time: 38.30s | Elapsed: 2327.47s | Est. Total: 2493.72s
# Iter 71/75 | Best Fitness: 8.442066 | Iter Time: 32.95s | Elapsed: 2360.42s | Est. Total: 2493.40s
# Iter 72/75 | Best Fitness: 8.442066 | Iter Time: 30.47s | Elapsed: 2390.89s | Est. Total: 2490.51s
# Iter 73/75 | Best Fitness: 8.442066 | Iter Time: 31.01s | Elapsed: 2421.90s | Est. Total: 2488.25s
# Iter 74/75 | Best Fitness: 8.442066 | Iter Time: 30.57s | Elapsed: 2452.47s | Est. Total: 2485.61s
# Iter 75/75 | Best Fitness: 8.442066 | Iter Time: 29.93s | Elapsed: 2482.40s | Est. Total: 2482.40s

# %%
c = best_params[0]
e = best_params[1]
g = best_params[2]
ESOA_svr = SVR(kernel='rbf', C=c, epsilon=e, gamma=g)

ESOA_svr.fit(X_train, y_train)

y_pred_optimized = ESOA_svr.predict(X_test)

# Evaluate the optimized model
accuracy_optimized = ESOA_svr.score(X_test, y_test)
mse_optimized = mean_squared_error(y_test, y_pred_optimized)
print(f"Mean Squared Error (SVR with ESOA optimization): {mse_optimized}")
print(f"Accuracy Score (SVR with ESOA optimization): {accuracy_optimized} %")
# Out:
# Mean Squared Error (SVR with ESOA optimization): 8.442066355287084
# Accuracy Score (SVR with ESOA optimization): 0.8848816194736474 %

# %%
diff = (accuracy_optimized - accuracy)* 100
print(f"diff in Accuracy: {diff:.2f} %")

improvement = (accuracy_optimized - accuracy) / accuracy * 100
print(f"Improvement in Accuracy: {improvement:.2f} %")
# Out:
# diff in Accuracy: 14.85 %
# Improvement in Accuracy: 20.17 %

# %%
plt.figure(figsize=(10, 6))
plt.plot(err, label='ESOA Error', color='blue')
plt.title('Error Convergence of ESOA') 
plt.xlabel('Iteration')
plt.ylabel('Error')
plt.axhline(y=0, color='red', linestyle='--')
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(y_test.values, label='True Values', color='blue')
plt.plot(y_pred, label='Predicted Values (SVR without ESOA)', color='orange')
plt.plot(y_pred_optimized, label='Predicted Values (SVR with ESOA)', color='green')
plt.title('SVR Predictions vs True Values')
plt.xlabel('Sample Index')
plt.ylabel('MEDV')
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, label='SVR without ESOA', color='orange', alpha=0.5)
plt.scatter(y_test, y_pred_optimized, label='SVR with ESOA', color='green', alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)
plt.title('SVR Predictions vs True Values')
plt.xlabel('True Values')
plt.ylabel('Predicted Values')
plt.legend()
plt.grid()
plt.show()
